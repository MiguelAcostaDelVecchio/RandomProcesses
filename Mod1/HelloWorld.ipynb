# %% [markdown]
# # Chapter 1
# This is chapter 1 of my document
#
# We can do words in _italics_
#
# We can do **boldface**
#
# $E=mc^2$
#
# $\int_0^4 \frac{x^2}{ln(x)}\ dx$

# %%
x = 4
y = 3
z = 7
print("the value is " , x+y+z)
# Out:
# the value is  14

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4,5] , [8,6,7,5,3])
plt.xlabel('time')
plt.ylabel('energy')
plt.show()
